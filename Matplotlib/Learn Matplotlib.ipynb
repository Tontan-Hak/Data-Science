# %% [markdown]
# ## Intorduction to matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %% [markdown]
# ## Making Plots Actually Look Nice

# %%
x = np.linspace(0,15,30)
y = np.sin(x) + 0.1*np.random.randn(len(x))

# %%
x
# Out:
# array([ 0.        ,  0.51724138,  1.03448276,  1.55172414,  2.06896552,
#         2.5862069 ,  3.10344828,  3.62068966,  4.13793103,  4.65517241,
#         5.17241379,  5.68965517,  6.20689655,  6.72413793,  7.24137931,
#         7.75862069,  8.27586207,  8.79310345,  9.31034483,  9.82758621,
#        10.34482759, 10.86206897, 11.37931034, 11.89655172, 12.4137931 ,
#        12.93103448, 13.44827586, 13.96551724, 14.48275862, 15.        ])

# %% [markdown]
# ## Quick Plotting
# ### Line Plots

# %%
plt.style.use(['default'])

# %%
plt.plot(x,y)

# %%
y
# Out:
# array([ 0.07853891,  0.35533898,  0.91209679,  1.12784316,  0.73470079,
#         0.50161437, -0.05142235, -0.48413049, -0.7803978 , -0.78693822,
#        -0.97117624, -0.5893926 ,  0.19490854,  0.31538959,  0.86929681,
#         0.97364862,  0.86389325,  0.54874592,  0.1287899 , -0.2819868 ,
#        -0.76799026, -0.98144529, -0.62008667, -0.74069982, -0.16976535,
#         0.47789992,  0.97422271,  0.85603327,  0.97969237,  0.74392464])

# %%
plt.plot(x,y,'o--', color='red',lw=0.7,ms=5)

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y,'o--', color='red',lw=0.7,ms=5)

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y,'o--', color='red',lw=0.7,ms=5)
plt.xlabel('Time[s]')
plt.ylabel('Voltage[v]')
# Out:
# Text(0, 0.5, 'Voltage[v]')

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y,'o--', color='red',lw=0.7,ms=5, label='Component 1')
plt.xlabel('Time[s]')
plt.ylabel('Voltage[v]')
plt.legend(loc='upper right',fontsize=10)

# %%
x2 = np.linspace(0,15,100)
y2 = np.sin(x2)

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y,'o--', color='red',lw=0.7,ms=5, label='Component 1')
plt.plot(x2,y2,'-', color='green',lw=0.7,ms=5, label='Component 2')
plt.xlabel('Time[s]')
plt.ylabel('Voltage[v]')
plt.legend(loc='upper right',fontsize=10)

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y,'o--', color='red',lw=0.7,ms=5, label='Data')
plt.plot(x2,y2,'-', color='green',lw=0.7,ms=5, label='Theory')
plt.xlabel('Time[s]')
plt.ylabel('Voltage[v]')
plt.ylim(top=1.5)
plt.legend(loc='upper right',fontsize=10, ncol=2)

# %% [markdown]
# ## Histagram

# %%
res = np.random.randn(1000)*0.2 + 0.4

# %%
res
# Out:
# array([ 0.66452499,  0.55927522,  0.34330214,  0.24156029,  0.50883008,
#         0.20926515,  0.32035207,  0.43662855,  0.46289686,  0.48720924,
#         0.3071575 ,  0.56319154,  0.5459642 ,  0.40527377,  0.25888076,
#         0.50721997,  0.54915483,  0.23821176,  0.0385326 ,  0.23400228,
#         0.38498805,  0.45390394,  0.40563498,  0.52171967,  0.92579389,
#         0.43917093,  0.59054259,  0.43456437,  0.30570629,  0.226864  ,
#         0.06610523,  0.36271178,  0.48858382,  0.213367  ,  0.40471333,
#         0.11029408,  0.04840067,  0.37764539,  0.20672327,  0.32321798,
#         0.14072069,  0.07506245, -0.03683809,  0.35445839,  0.3753372 ,
#         0.02468953,  0.42833644,  0.50999131,  0.67970539,  0.21913194,
#         0.50882247,  0.95076859,  0.4647767 ,  0.67656214,  0.40235333,
#         0.0977774 ,  0.4316419 ,  0.58128674,  0.21728185,  0.64994525,
#         0.86043195,  0.03727271,  0.38709718,  0.74610598,  0.57434806,
# ...

# %%
a= plt.hist(res)

# %%
a
# Out:
# (array([  1.,  10.,  36., 106., 218., 259., 191., 115.,  46.,  18.]),
#  array([-0.30006214, -0.17349827, -0.0469344 ,  0.07962947,  0.20619334,
#          0.3327572 ,  0.45932107,  0.58588494,  0.71244881,  0.83901268,
#          0.96557654]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(8,3))
plt.hist(res,bins=50, density=True)
plt.show()

# %%
res2 = np.random.randn(1000)*0.2 + 0.4

# %%
plt.figure(figsize=(8,3))
plt.hist(res,bins=50, density=True, histtype='step')
plt.hist(res2,bins=30, density=True, histtype='step')
plt.show()

# %% [markdown]
# ## A more advanced API
# For more complicated plots, such as
# * Multiple subplots on 1 figure
# * Conveniently adding text to plots
# * Creating animations
# one needs to use a slightly more advanced API
#
# ### Single Axes in one Figure

# %%
fig, ax=plt.subplots(1,1,figsize=(12,4))
ax.plot(x,y, "o--")
ax.set_xlabel('asd')
ax.set_ylabel('asdasasd')
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(12,4))

# %%
fig, axes =plt.subplots(3,2,figsize=(12,12))
#ax.plot(x,y, "o--")
#ax.set_xlabel('asd')
#ax.set_ylabel('asdasasd')
#plt.show()

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.animation as animation
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from moviepy.editor import VideoClip
from moviepy.video.io.bindings import mplfig_to_npimage

# %%
fig, axes =plt.subplots(3,2,figsize=(12,12))
ax = axes[0][0]
ax.plot(x,y, "o--")
ax.set_xlabel('asd')
ax.set_ylabel('asdasasd')
ax.tick_params(axis='both',labelsize=10)
ax = axes[1][1]
ax.plot(x,y, "o--")
ax.set_xlabel('asd')
ax.set_ylabel('asdasasd')
ax.set_title('Histogram')
plt.show()

# %% [markdown]
# ## Examples
# Create the following plot

# %%
res_a1 = 0.2*np.random.randn(1000)+0.4
res_b1 = 0.25*np.random.randn(1000)+0.4
res_a2 = 0.21*np.random.randn(1000)+0.3
res_b2 = 0.22*np.random.randn(1000)+0.3

# %%
res_a1
# Out:
# array([ 0.56916088,  0.38638718,  0.38619911,  0.42600635,  0.52708196,
#         0.25220411,  0.44861847,  0.40619219,  0.67965058,  0.23722031,
#         0.43808696,  0.63628049,  0.51071216,  0.49182503,  0.47509947,
#         0.58710714,  0.15414623,  0.42601422,  0.29996447,  0.28177256,
#         0.55101535,  0.18868558,  0.4093162 ,  0.16212425,  0.65815239,
#         0.64794391,  0.29345349,  0.86813404,  0.51808692,  0.31443262,
#         0.28194014,  0.34110223,  0.55244665,  0.35531861,  0.49383797,
#         0.68757001,  0.21757105,  0.49698365,  0.83464275,  0.53331292,
#         0.33099705,  0.45604228,  0.53521137,  0.07069761,  0.32323716,
#         0.28427198,  0.62505933,  0.20352263,  0.65634377,  0.22584083,
#         0.52386571,  0.3574587 ,  0.60161123,  0.64473281,  0.43521752,
#         0.47767712,  0.23412919,  0.55155212,  0.25692043,  0.42170228,
#         0.54969557,  0.23949387,  0.63381917,  0.3489967 ,  0.60839322,
# ...

# %%
plt.hist(res_a1, bins = 100)
plt.hist(res_b2 , bins = 100)
plt.show()

# %% [markdown]
# ## 2D Plots
# Generate some data

# %%
A = np.linspace(-1,1,100)
x,y = np.meshgrid(A,A)
z =x**2 + y*x

# %%
plt.contourf(x,y,z, levels=30,vmin=0.5,cmap='plasma')
plt.colorbar(label="asd")

# %% [markdown]
# ## Contour Plot
# Sometimes, the following is preferred:

# %%
cs =plt.contour(x,y,z)
plt.clabel(cs,fontsize=8)
# Out:
# <a list of 14 text.Text objects>

# %%
fig, ax =plt.subplots(subplot_kw={'projection':3d})
ax.plot_surface(x,y,z,cmap='coolwarm')
# Out:
#   Input In [92]
#     fig, ax =plt.subplots(subplot_kw={'projection':3d})
#                                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## SteamPlots
# For plotting vector fields

# %%
w = 3
_ = np.linspace(-3,3,100)
X,Y =np.meshgrid(_,_)
U = -1 - X**2+Y
V = 1 +X -Y**2
speed =np.sqrt(U**2 + V**2)

# %% [markdown]
# ## Image Reading
# Plot Image

# %% [markdown]
# ## Animations
# Animations require relating the time of your problem to the frame of the animation, then specifiyiny the frames per second
# * Below is a sin wave moving at 3m/s. Translate this into an animation

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

# %%
textstr1 = '\n'.join((
    r'$\sigma_a=%.4f$' % (np.std(res_a1)),
    r'$\sigma_b=%.4f$' % (np.std(res_b1))))

textstr2 = '\n'.join((
    r'$\sigma_a=%.4f$' % (np.std(res_a2)),
    r'$\sigma_b=%.4f$' % (np.std(res_b2))))

# %%
def f(x,t):
    return np.sin(x-3*t)
x = np.linspace(0,10*np.pi,1000)

# %%
plt.plot(x,f(x,0))
plt.plot(x,f(x,0.1))
